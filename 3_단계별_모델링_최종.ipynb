# %% [markdown]
# #**스마트폰 센서 데이터 기반 모션 분류**
# # 단계3 : 단계별 모델링

# %% [markdown]
# ## 0.미션4

# %% [markdown]
# * 단계별로 나눠서 모델링을 수행하고자 합니다.
# * 단계 구분 예시
#     * 단계1 : 정적(0), 동적(1) 행동 분류 모델 생성
#     * 단계2 : 세부 동작에 대한 분류모델 생성
#         * 단계1 모델에서 0으로 예측 -> 정적 행동 3가지 분류 모델링
#         * 단계1 모델에서 1으로 예측 -> 동적 행동 3가지 분류 모델링
# * 모델 통합
#     * 두 단계 모델을 통합하고, 새로운 데이터에 대해서 최종 예측결과와 성능평가가 나오도록 함수로 만들기
# * 성능 비교
#     * 기본 모델링의 성능과 비교
#     * 성능 가이드
#         * Accuracy : 0.97 ~ 0.99
# * 파이프라인 구성
#     * test 데이터를 입력하여, 전처리 및 예측결과가 나오도록 함수 구성

# %% [markdown]
# ## 1.환경설정

# %% [markdown]
# * 세부 요구사항
#     - 경로 설정 : 구글콜랩
#         * 구글 드라이브 바로 밑에 project3 폴더를 만들고,
#         * 데이터 파일을 복사해 넣습니다.
#     - 기본적으로 필요한 라이브러리를 import 하도록 코드가 작성되어 있습니다.
#         * 필요하다고 판단되는 라이브러리를 추가하세요.

# %% [markdown]
# ### (1) 경로 설정

# %% [markdown]
# * 구글 드라이브 연결

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/project3/'

# %% [markdown]
# ### (2) 라이브러리 불러오기

# %% [markdown]
# * 라이브러리 로딩

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import joblib

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.metrics import *

from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, Input
from keras.backend import clear_session
from keras.optimizers import Adam

# %%
# 학습곡선 함수
def dl_history_plot(history):
    plt.figure(figsize=(10,6))
    plt.plot(history['loss'], label='train_err', marker = '.')
    plt.plot(history['val_loss'], label='val_err', marker = '.')

    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ### (3) 데이터 불러오기

# %% [markdown]
# * 주어진 데이터셋
#     * data01_train.csv : 학습 및 검증용
#     * data01_test.csv : 테스트용
#     * feature.csv : feature 이름을 계층구조로 정리한 데이터
#
# * 세부 요구사항
#     * 칼럼 삭제 : data01_train.csv와 data01_test.csv 에서 'subject' 칼럼은 불필요하므로 삭제합니다.

# %% [markdown]
# #### 1) 데이터로딩

# %%
file1 = 'data01_train.csv'
file2 = 'data01_test.csv'
file3 = 'features.csv'

# %%
data = pd.read_csv(path + file1)
test = pd.read_csv(path + file2)
features = pd.read_csv(path + file3)

# %%
# 불필요한 칼럼 삭제
data.drop('subject', axis=1, inplace=True)
test.drop('subject', axis=1, inplace=True)

# %% [markdown]
# #### 2) 기본 정보 조회

# %%
#전체 데이터의 행,열 개수 확인
data.shape
# Out:
# (5881, 562)

# %%
#전체 데이터의 상위 5개 행 확인
data.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288508          -0.009196          -0.103362         -0.988986
# 1           0.265757          -0.016576          -0.098163         -0.989551
# 2           0.278709          -0.014511          -0.108717         -0.997720
# 3           0.289795          -0.035536          -0.150354         -0.231727
# 4           0.394807           0.034098           0.091229          0.088489
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.962797         -0.967422         -0.989000         -0.962596
# 1         -0.994636         -0.987435         -0.990189         -0.993870
# 2         -0.981088         -0.994008         -0.997934         -0.982187
# 3         -0.006412         -0.338117         -0.273557          0.014245
# 4         -0.106636         -0.388502         -0.010469         -0.109680
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-skewness()  \
# 0         -0.965650         -0.929747  ...                        -0.487737
# 1         -0.987558         -0.937337  ...                        -0.237820
# 2         -0.995017         -0.942584  ...                        -0.535287
# 3         -0.347916          0.008288  ...                        -0.004012
# 4         -0.346372          0.584131  ...                        -0.157832
#
#    fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# 0                        -0.816696                    -0.042494
# 1                        -0.693515                    -0.062899
# 2                        -0.829311                     0.000265
# 3                        -0.408956                    -0.255125
# 4                        -0.563437                    -0.044344
#
#    angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# 0                             -0.044218                          0.307873
# 1                              0.388459                         -0.765014
# 2                             -0.525022                         -0.891875
# 3                              0.612804                          0.747381
# 4                             -0.845268                         -0.974650
#
#    angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 0                              0.072790             -0.601120
# 1                              0.771524              0.345205
# 2                              0.021528             -0.833564
# 3                             -0.072944             -0.695819
# 4                             -0.887846             -0.705029
#
#    angle(Y,gravityMean)  angle(Z,gravityMean)            Activity
# 0              0.331298              0.165163            STANDING
# 1             -0.769186             -0.147944              LAYING
# 2              0.202434             -0.032755            STANDING
# 3              0.287154              0.111388             WALKING
# 4              0.264952              0.137758  WALKING_DOWNSTAIRS
#
# [5 rows x 562 columns]

# %%
#전체 데이터의 수치형 변수 분포 확인
data.describe()
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# count        5881.000000        5881.000000        5881.000000
# mean            0.274811          -0.017799          -0.109396
# std             0.067614           0.039422           0.058373
# min            -0.503823          -0.684893          -1.000000
# 25%             0.262919          -0.024877          -0.121051
# 50%             0.277154          -0.017221          -0.108781
# 75%             0.288526          -0.010920          -0.098163
# max             1.000000           1.000000           1.000000
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# count       5881.000000       5881.000000       5881.000000       5881.000000
# mean          -0.603138         -0.509815         -0.604058         -0.628151
# std            0.448807          0.501815          0.417319          0.424345
# min           -1.000000         -0.999844         -0.999667         -1.000000
# 25%           -0.992774         -0.977680         -0.980127         -0.993602
# 50%           -0.943933         -0.844575         -0.856352         -0.948501
# 75%           -0.242130         -0.034499         -0.262690         -0.291138
# max            1.000000          0.916238          1.000000          1.000000
#
#        tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# count       5881.000000       5881.000000       5881.000000  ...
# mean          -0.525944         -0.605374         -0.465490  ...
# std            0.485115          0.413043          0.544995  ...
# min           -0.999419         -1.000000         -1.000000  ...
# 25%           -0.977865         -0.980112         -0.936067  ...
# 50%           -0.849266         -0.849896         -0.878729  ...
# 75%           -0.068857         -0.268539         -0.013690  ...
# max            0.967664          1.000000          1.000000  ...
#
#        fBodyBodyGyroJerkMag-meanFreq()  fBodyBodyGyroJerkMag-skewness()  \
# count                      5881.000000                      5881.000000
# mean                          0.126955                        -0.305883
# std                           0.249176                         0.322808
# min                          -0.965725                        -0.979261
# 25%                          -0.021610                        -0.541969
# 50%                           0.133887                        -0.342923
# 75%                           0.288944                        -0.127371
# max                           0.946700                         0.989538
#
#        fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# count                      5881.000000                  5881.000000
# mean                         -0.623548                     0.008524
# std                           0.310371                     0.339730
# min                          -0.999765                    -0.976580
# 25%                          -0.845985                    -0.122361
# 50%                          -0.712677                     0.010278
# 75%                          -0.501158                     0.154985
# max                           0.956845                     1.000000
#
#        angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# count                           5881.000000                       5881.000000
# mean                              -0.001185                          0.009340
# std                                0.447197                          0.608190
# min                               -1.000000                         -1.000000
# 25%                               -0.294369                         -0.481718
# 50%                                0.005146                          0.011448
# 75%                                0.285030                          0.499857
# max                                1.000000                          0.998702
#
#        angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# count                           5881.000000           5881.000000
# mean                              -0.007099             -0.491501
# std                                0.476738              0.509069
# min                               -1.000000             -1.000000
# 25%                               -0.373345             -0.811397
# 50%                               -0.000847             -0.709441
# 75%                                0.356236             -0.511330
# max                                0.996078              0.977344
#
#        angle(Y,gravityMean)  angle(Z,gravityMean)
# count           5881.000000           5881.000000
# mean               0.059299             -0.054594
# std                0.297340              0.278479
# min               -1.000000             -0.980143
# 25%               -0.018203             -0.141555
# 50%                0.182893              0.003951
# 75%                0.248435              0.111932
# max                0.478157              1.000000
#
# [8 rows x 561 columns]

# %%
#전체 데이터의 모든 변수 확인
data.columns
# Out:
# Index(['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z',
#        'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z',
#        'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z',
#        'tBodyAcc-max()-X',
#        ...
#        'fBodyBodyGyroJerkMag-skewness()', 'fBodyBodyGyroJerkMag-kurtosis()',
#        'angle(tBodyAccMean,gravity)', 'angle(tBodyAccJerkMean),gravityMean)',
#        'angle(tBodyGyroMean,gravityMean)',
#        'angle(tBodyGyroJerkMean,gravityMean)', 'angle(X,gravityMean)',
#        'angle(Y,gravityMean)', 'angle(Z,gravityMean)', 'Activity'],
#       dtype='object', length=562)

# %% [markdown]
# ## 2.데이터 전처리

# %% [markdown]
# * 세부 요구사항
#     - Label 추가 : 1단계 모델을 위한 레이블 추가
#     - train : val = 8 : 2 혹은 7 : 3
#     - random_state 옵션을 사용하여 다른 모델과 비교를 위해 성능이 재현되도록 합니다.

# %% [markdown]
# ### (1) 1단계 모델링을 위한 레이블

# %%
static_activities = ['STANDING', 'SITTING', 'LAYING']
dynamic_activities = ['WALKING', 'WALKING_UPSTAIRS', 'WALKING_DOWNSTAIRS']
data['is_dynamic'] = data['Activity'].apply(lambda x: 0 if x in static_activities else 1)
data.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288508          -0.009196          -0.103362         -0.988986
# 1           0.265757          -0.016576          -0.098163         -0.989551
# 2           0.278709          -0.014511          -0.108717         -0.997720
# 3           0.289795          -0.035536          -0.150354         -0.231727
# 4           0.394807           0.034098           0.091229          0.088489
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.962797         -0.967422         -0.989000         -0.962596
# 1         -0.994636         -0.987435         -0.990189         -0.993870
# 2         -0.981088         -0.994008         -0.997934         -0.982187
# 3         -0.006412         -0.338117         -0.273557          0.014245
# 4         -0.106636         -0.388502         -0.010469         -0.109680
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-kurtosis()  \
# 0         -0.965650         -0.929747  ...                        -0.816696
# 1         -0.987558         -0.937337  ...                        -0.693515
# 2         -0.995017         -0.942584  ...                        -0.829311
# 3         -0.347916          0.008288  ...                        -0.408956
# 4         -0.346372          0.584131  ...                        -0.563437
#
#    angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                    -0.042494                             -0.044218
# 1                    -0.062899                              0.388459
# 2                     0.000265                             -0.525022
# 3                    -0.255125                              0.612804
# 4                    -0.044344                             -0.845268
#
#    angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                          0.307873                              0.072790
# 1                         -0.765014                              0.771524
# 2                         -0.891875                              0.021528
# 3                          0.747381                             -0.072944
# 4                         -0.974650                             -0.887846
#
#    angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 0             -0.601120              0.331298              0.165163
# 1              0.345205             -0.769186             -0.147944
# 2             -0.833564              0.202434             -0.032755
# 3             -0.695819              0.287154              0.111388
# 4             -0.705029              0.264952              0.137758
#
#              Activity  is_dynamic
# 0            STANDING           0
# 1              LAYING           0
# 2            STANDING           0
# 3             WALKING           1
# 4  WALKING_DOWNSTAIRS           1
#
# [5 rows x 563 columns]

# %% [markdown]
# ### (2) x, y 분리

# %%
target = 'is_dynamic'
target_2 = 'Activity'
data.drop(columns = target_2, inplace=True)
x = data.drop(columns = target)
y = data.loc[:, target]

# %% [markdown]
# ### (3) 스케일링

# %% [markdown]
# * 세부 요구사항
#     - 스케일링을 필요로 하는 알고리즘 사용을 위해서 코드 수행
#     - min-max 방식 혹은 standard 방식 중 한가지 사용.

# %%
# 기본 데이터가 -1~1이면 scaling 안해도 된다.

# %%
# scaler = MinMaxScaler()
# x = scaler.fit_transform(x)

# %% [markdown]
# ### (4) 데이터 분할
# * train, val 분할

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size = .2, random_state = 20)

# %% [markdown]
# ## **3.단계별 모델링**

# %% [markdown]
# ### (1) 단계1

# %% [markdown]
# * 세부 요구사항
#     * 적절한 단계로 구분한 후, 1단계를 분류하는 모델 생성
#         * 예시 : 정적 행동(Laying, Sitting, Standing)과 동적 행동(동적 : Walking, Walking-Up, Walking-Down)을 구분하는 모델 생성.
#     * 몇 가지 모델을 만들고 가장 성능이 좋은 모델을 선정하시오.

# %% [markdown]
# #### 1) 모델1

# %%
n = x_train.shape[1]
n
# Out:
# 561

# %%
model1 = Sequential( [Input(shape = (n,)),
                     Dense(60, activation='relu'),
                     Dropout(0.3),
                     Dense(80, activation='relu'),
                     Dropout(0.4),
                     Dense(40, activation='relu'),
                     Dropout(0.1),
                     Dense(20, activation='relu'),
                     Dense(2, activation = 'softmax')] )

model1.compile(optimizer = Adam(learning_rate = 0.0002), loss = 'sparse_categorical_crossentropy')

model1.fit(x_train, y_train, epochs = 100, validation_split = 0.2)

pred1 = model1.predict(x_val)
pred1 = np.argmax(pred1, axis = 1)

print("Accuracy: ", accuracy_score(y_val, pred1))
# Out:
# Epoch 1/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 69s 18ms/step - loss: 0.2857 - val_loss: 0.0035
# Epoch 2/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0059 - val_loss: 0.0013
# Epoch 3/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017 - val_loss: 7.8346e-04
# Epoch 4/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 8.8303e-04 - val_loss: 6.0663e-04
# Epoch 5/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.7624e-04 - val_loss: 5.0179e-04
# Epoch 6/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.5419e-04 - val_loss: 3.5761e-04
# Epoch 7/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 3.6143e-04 - val_loss: 2.3979e-04
# Epoch 8/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.5768e-04 - val_loss: 1.9598e-04
# Epoch 9/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0883e-04 - val_loss: 1.5646e-04
# Epoch 10/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0962e-04 - val_loss: 1.1488e-04
# Epoch 11/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7763e-05 - val_loss: 9.0063e-05
# Epoch 12/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.9161e-05 - val_loss: 7.6328e-05
# Epoch 13/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.9859e-05 - val_loss: 6.1290e-05
# Epoch 14/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.0580e-05 - val_loss: 5.4514e-05
# Epoch 15/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.6016e-05 - val_loss: 4.7386e-05
# Epoch 16/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 2.3821e-05 - val_loss: 4.5027e-05
# Epoch 17/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 2.0522e-05 - val_loss: 4.3380e-05
# Epoch 18/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.9370e-05 - val_loss: 3.9323e-05
# Epoch 19/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.9099e-05 - val_loss: 3.5146e-05
# Epoch 20/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.6878e-06 - val_loss: 2.9805e-05
# Epoch 21/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.0420e-05 - val_loss: 2.6672e-05
# Epoch 22/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.2652e-05 - val_loss: 2.4845e-05
# Epoch 23/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.0700e-06 - val_loss: 2.3028e-05
# Epoch 24/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.9318e-06 - val_loss: 2.2352e-05
# Epoch 25/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.5118e-05 - val_loss: 2.4306e-05
# Epoch 26/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.7319e-06 - val_loss: 2.3473e-05
# Epoch 27/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.9598e-06 - val_loss: 2.0660e-05
# Epoch 28/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 7.6250e-06 - val_loss: 1.5695e-05
# Epoch 29/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 6.4318e-06 - val_loss: 1.2500e-05
# Epoch 30/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 2.9566e-06 - val_loss: 1.1750e-05
# Epoch 31/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 8.9140e-06 - val_loss: 9.6797e-06
# Epoch 32/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.4586e-06 - val_loss: 9.2325e-06
# Epoch 33/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 8.7342e-07 - val_loss: 9.0315e-06
# Epoch 34/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.2654e-06 - val_loss: 8.9700e-06
# Epoch 35/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 8.0464e-06 - val_loss: 4.6470e-06
# Epoch 36/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.0790e-06 - val_loss: 4.5023e-06
# Epoch 37/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.1487e-06 - val_loss: 3.7504e-06
# Epoch 38/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.9497e-07 - val_loss: 3.7347e-06
# Epoch 39/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 7.9516e-07 - val_loss: 3.6496e-06
# Epoch 40/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.1190e-06 - val_loss: 3.4220e-06
# Epoch 41/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.6562e-06 - val_loss: 2.9959e-06
# Epoch 42/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.5208e-06 - val_loss: 2.6272e-06
# Epoch 43/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.8459e-06 - val_loss: 2.2780e-06
# Epoch 44/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.9321e-06 - val_loss: 2.1230e-06
# Epoch 45/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.1702e-07 - val_loss: 2.0976e-06
# Epoch 46/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.0273e-07 - val_loss: 2.0684e-06
# Epoch 47/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 9.8713e-07 - val_loss: 2.0159e-06
# Epoch 48/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.9840e-06 - val_loss: 1.9886e-06
# Epoch 49/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 6.0304e-07 - val_loss: 1.7025e-06
# Epoch 50/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 6.2978e-06 - val_loss: 2.2695e-06
# Epoch 51/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 6.2629e-07 - val_loss: 2.1607e-06
# Epoch 52/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 8.2181e-07 - val_loss: 2.1387e-06
# Epoch 53/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 1.0121e-07 - val_loss: 2.1179e-06
# Epoch 54/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 4.3555e-06 - val_loss: 1.6344e-06
# Epoch 55/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 3.3080e-07 - val_loss: 1.5298e-06
# Epoch 56/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.0085e-06 - val_loss: 1.3627e-06
# Epoch 57/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.5045e-07 - val_loss: 1.2093e-06
# Epoch 58/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 3.9751e-07 - val_loss: 1.0685e-06
# Epoch 59/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.8993e-07 - val_loss: 1.0493e-06
# Epoch 60/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 4.6893e-08 - val_loss: 1.0382e-06
# Epoch 61/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 5.1661e-07 - val_loss: 1.0470e-06
# Epoch 62/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.4674e-07 - val_loss: 1.0351e-06
# Epoch 63/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.5866e-07 - val_loss: 1.0293e-06
# Epoch 64/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.6981e-08 - val_loss: 9.6915e-07
# Epoch 65/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6335e-06 - val_loss: 4.6285e-07
# Epoch 66/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.5809e-06 - val_loss: 2.3878e-07
# Epoch 67/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 8.2588e-08 - val_loss: 2.2536e-07
# Epoch 68/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.2513e-07 - val_loss: 2.2878e-07
# Epoch 69/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.4161e-07 - val_loss: 2.2928e-07
# Epoch 70/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 2.9848e-08 - val_loss: 2.2814e-07
# Epoch 71/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.3922e-07 - val_loss: 2.1510e-07
# Epoch 72/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.2452e-08 - val_loss: 2.1383e-07
# Epoch 73/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.7331e-07 - val_loss: 2.0560e-07
# Epoch 74/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.3213e-08 - val_loss: 2.0091e-07
# Epoch 75/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.1012e-07 - val_loss: 1.9774e-07
# Epoch 76/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.5107e-08 - val_loss: 1.9749e-07
# Epoch 77/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.8372e-06 - val_loss: 1.6582e-07
# Epoch 78/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.8001e-08 - val_loss: 1.6582e-07
# Epoch 79/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 1.5581e-07 - val_loss: 1.6189e-07
# Epoch 80/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 2.3934e-08 - val_loss: 1.6417e-07
# Epoch 81/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.8381e-08 - val_loss: 1.6329e-07
# Epoch 82/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 1.8114e-08 - val_loss: 1.6240e-07
# Epoch 83/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.2805e-08 - val_loss: 1.3795e-07
# Epoch 84/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.1401e-08 - val_loss: 1.3162e-07
# Epoch 85/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 3.0289e-09 - val_loss: 1.3099e-07
# Epoch 86/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.2095e-09 - val_loss: 1.2871e-07
# Epoch 87/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.2777e-08 - val_loss: 1.3567e-07
# Epoch 88/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.2670e-08 - val_loss: 1.3669e-07
# Epoch 89/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.4066e-08 - val_loss: 1.4074e-07
# Epoch 90/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.3989e-08 - val_loss: 1.3479e-07
# Epoch 91/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.1820e-08 - val_loss: 1.1046e-07
# Epoch 92/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.1451e-08 - val_loss: 1.1046e-07
# Epoch 93/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.4998e-08 - val_loss: 1.1008e-07
# Epoch 94/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.7694e-07 - val_loss: 1.2655e-07
# Epoch 95/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.2442e-08 - val_loss: 1.4213e-07
# Epoch 96/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 1.0913e-08 - val_loss: 1.3099e-07
# Epoch 97/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 1.4546e-08 - val_loss: 1.2275e-07
# Epoch 98/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 5.9545e-10 - val_loss: 1.2263e-07
# Epoch 99/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.7277e-10 - val_loss: 1.2275e-07
# Epoch 100/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 7.1465e-09 - val_loss: 1.2187e-07
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Accuracy:  1.0

# %% [markdown]
# #### 2) 모델2

# %%
from keras.callbacks import EarlyStopping

es = EarlyStopping(monitor = 'val_loss', min_delta = 0.0001, patience = 5)

model2 = Sequential([Input(shape=(n,)),
                   Dense(1000, activation='relu'),
                   Dropout(0.3),
                   Dense(1000, activation='relu'),
                   Dropout(0.3),
                   Dense(500, activation='relu'),
                   Dropout(0.3),
                   Dense(100, activation='relu'),
                   Dropout(0.3),
                   Dense(1, activation='sigmoid')])

model2.compile(optimizer = Adam(learning_rate = 0.0001), loss = 'binary_crossentropy')

model2.fit(x_train, y_train, epochs = 100, validation_split = 0.2, callbacks = [es])

pred2 = model2.predict(x_val)
pred2 = np.where(pred2 >= 0.5, 1, 0)

print("Accuracy: ", accuracy_score(y_val, pred2))
# Out:
# Epoch 1/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - loss: 0.2078 - val_loss: 1.2002e-04
# Epoch 2/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - loss: 0.0030 - val_loss: 2.5063e-05
# Epoch 3/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 10s 49ms/step - loss: 0.0030 - val_loss: 5.7354e-05
# Epoch 4/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 15s 85ms/step - loss: 0.0010 - val_loss: 2.1956e-04
# Epoch 5/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 8s 70ms/step - loss: 0.0025 - val_loss: 7.8268e-06
# Epoch 6/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - loss: 0.0023 - val_loss: 3.9257e-06
# Epoch 7/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - loss: 2.3435e-04 - val_loss: 9.0766e-06
# Epoch 8/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - loss: 2.5220e-04 - val_loss: 1.0154e-06
# Epoch 9/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - loss: 8.2417e-05 - val_loss: 2.1063e-06
# Epoch 10/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 6.3861e-05 - val_loss: 6.7244e-07
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Accuracy:  1.0

# %% [markdown]
# ### (2) 단계2

# %% [markdown]
# #### 1) 단계2-1 : 정적 동작 세부 분류

# %% [markdown]
# * 세부 요구사항
#     * 정적 행동(Laying, Sitting, Standing)인 데이터 추출
#     * Laying, Sitting, Standing 를 분류하는 모델을 생성
#     * 몇가지 모델을 만들고 가장 성능이 좋은 모델을 선정하시오.

# %% [markdown]
# pred
#
# 0: Laying
# 1: Sitting
# 2: Standing

# %% [markdown]
# #### 모델 2-1-1

# %%
# 제일 위에 데이터 불러오고 밑에 코드들 순서대로 실행했습니다.

static_activities = ['STANDING', 'SITTING', 'LAYING']
dynamic_activities = ['WALKING', 'WALKING_UPSTAIRS', 'WALKING_DOWNSTAIRS']
data['is_dynamic'] = data['Activity'].apply(lambda x: 0 if x in static_activities else 1)
data.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288508          -0.009196          -0.103362         -0.988986
# 1           0.265757          -0.016576          -0.098163         -0.989551
# 2           0.278709          -0.014511          -0.108717         -0.997720
# 3           0.289795          -0.035536          -0.150354         -0.231727
# 4           0.394807           0.034098           0.091229          0.088489
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.962797         -0.967422         -0.989000         -0.962596
# 1         -0.994636         -0.987435         -0.990189         -0.993870
# 2         -0.981088         -0.994008         -0.997934         -0.982187
# 3         -0.006412         -0.338117         -0.273557          0.014245
# 4         -0.106636         -0.388502         -0.010469         -0.109680
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-kurtosis()  \
# 0         -0.965650         -0.929747  ...                        -0.816696
# 1         -0.987558         -0.937337  ...                        -0.693515
# 2         -0.995017         -0.942584  ...                        -0.829311
# 3         -0.347916          0.008288  ...                        -0.408956
# 4         -0.346372          0.584131  ...                        -0.563437
#
#    angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                    -0.042494                             -0.044218
# 1                    -0.062899                              0.388459
# 2                     0.000265                             -0.525022
# 3                    -0.255125                              0.612804
# 4                    -0.044344                             -0.845268
#
#    angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                          0.307873                              0.072790
# 1                         -0.765014                              0.771524
# 2                         -0.891875                              0.021528
# 3                          0.747381                             -0.072944
# 4                         -0.974650                             -0.887846
#
#    angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 0             -0.601120              0.331298              0.165163
# 1              0.345205             -0.769186             -0.147944
# 2             -0.833564              0.202434             -0.032755
# 3             -0.695819              0.287154              0.111388
# 4             -0.705029              0.264952              0.137758
#
#              Activity  is_dynamic
# 0            STANDING           0
# 1              LAYING           0
# 2            STANDING           0
# 3             WALKING           1
# 4  WALKING_DOWNSTAIRS           1
#
# [5 rows x 563 columns]

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
data['Activity'] = encoder.fit_transform(data['Activity'])

# %%
df_0 = data.loc[data['Activity'].isin([0, 1, 2])]

# x, y 분리
target = 'Activity'
x0 = df_0.drop([target,'is_dynamic'], axis = 1)
y0 = df_0.loc[:, target]

# 데이터 분할
x_train0, x_val0, y_train0, y_val0 = train_test_split(x0, y0, test_size = .3, random_state = 20)

# %%
from keras.regularizers import l1, l2

clear_session()

n = x_train0.shape[1]

model3 = Sequential([Input(shape = (n, )),
                     Dense(512, activation = 'relu', kernel_regularizer = l1(0.001)),
                     Dense(256, activation = 'relu', kernel_regularizer = l1(0.001)),
                     Dense(128, activation = 'relu', kernel_regularizer = l1(0.001)),
                     Dense(64, activation = 'relu', kernel_regularizer = l1(0.001)),
                     Dense(32, activation = 'relu', kernel_regularizer = l1(0.001)),
                     Dense(3, activation = 'softmax')])


model3.compile(optimizer = Adam(learning_rate = 0.0005), loss = 'sparse_categorical_crossentropy')

model3.fit(x_train0, y_train0, epochs = 100, validation_split = 0.2)

pred3 = model3.predict(x_val0)
pred3 = np.argmax(pred3, axis = 1)

print("Accuracy: ", accuracy_score(y_val0, pred3))
# Out:
# Epoch 1/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 18.2846 - val_loss: 12.4745
# Epoch 2/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 11.0780 - val_loss: 7.6799
# Epoch 3/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.8609 - val_loss: 5.2956
# Epoch 4/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.0351 - val_loss: 4.3351
# Epoch 5/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.1573 - val_loss: 3.7553
# Epoch 6/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.6077 - val_loss: 3.8186
# Epoch 7/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.3498 - val_loss: 3.0093
# Epoch 8/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.8990 - val_loss: 2.6923
# Epoch 9/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.6307 - val_loss: 2.4563
# Epoch 10/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.3904 - val_loss: 2.2492
# Epoch 11/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.2018 - val_loss: 2.1152
# Epoch 12/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 2.0435 - val_loss: 1.9333
# Epoch 13/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.9320 - val_loss: 1.8216
# Epoch 14/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.7612 - val_loss: 1.6883
# Epoch 15/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.6566 - val_loss: 1.6258
# Epoch 16/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.5795 - val_loss: 1.5011
# Epoch 17/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.4590 - val_loss: 1.4904
# Epoch 18/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.3988 - val_loss: 1.3495
# Epoch 19/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.3096 - val_loss: 1.3123
# Epoch 20/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 1.2538 - val_loss: 1.2109
# Epoch 21/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.1751 - val_loss: 1.1702
# Epoch 22/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.1771 - val_loss: 1.1874
# Epoch 23/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.1657 - val_loss: 1.0767
# Epoch 24/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.0518 - val_loss: 1.0266
# Epoch 25/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.9857 - val_loss: 0.9789
# Epoch 26/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.9824 - val_loss: 0.9409
# Epoch 27/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.9110 - val_loss: 0.8993
# Epoch 28/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.8924 - val_loss: 0.8802
# Epoch 29/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.9132 - val_loss: 0.8459
# Epoch 30/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.8054 - val_loss: 0.9092
# Epoch 31/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.7931 - val_loss: 0.7840
# Epoch 32/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.7592 - val_loss: 0.8040
# Epoch 33/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.7477 - val_loss: 0.7441
# Epoch 34/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.6917 - val_loss: 0.8082
# Epoch 35/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.6943 - val_loss: 0.7315
# Epoch 36/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.6729 - val_loss: 0.6745
# Epoch 37/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.6425 - val_loss: 0.6728
# Epoch 38/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.6296 - val_loss: 0.6656
# Epoch 39/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.7375 - val_loss: 0.6685
# Epoch 40/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.6048 - val_loss: 0.6402
# Epoch 41/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5676 - val_loss: 0.6491
# Epoch 42/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.5652 - val_loss: 0.6226
# Epoch 43/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.5515 - val_loss: 0.5626
# Epoch 44/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5223 - val_loss: 0.5573
# Epoch 45/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5119 - val_loss: 0.5600
# Epoch 46/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5146 - val_loss: 0.5679
# Epoch 47/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.4941 - val_loss: 0.5061
# Epoch 48/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.4796 - val_loss: 0.4991
# Epoch 49/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.4697 - val_loss: 0.5060
# Epoch 50/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.4417 - val_loss: 0.4906
# Epoch 51/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.4504 - val_loss: 0.4651
# Epoch 52/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4354 - val_loss: 0.4837
# Epoch 53/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.4166 - val_loss: 0.5099
# Epoch 54/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4055 - val_loss: 0.4388
# Epoch 55/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.3978 - val_loss: 0.4311
# Epoch 56/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3948 - val_loss: 0.4211
# Epoch 57/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.4216 - val_loss: 0.4563
# Epoch 58/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.3960 - val_loss: 0.4187
# Epoch 59/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.3760 - val_loss: 0.4007
# Epoch 60/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3639 - val_loss: 0.4019
# Epoch 61/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.3828 - val_loss: 0.4457
# Epoch 62/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.3879 - val_loss: 0.3846
# Epoch 63/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.3441 - val_loss: 0.3808
# Epoch 64/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.3401 - val_loss: 0.3736
# Epoch 65/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.3858 - val_loss: 0.3806
# Epoch 66/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3666 - val_loss: 0.3726
# Epoch 67/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.3262 - val_loss: 0.3622
# Epoch 68/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.3237 - val_loss: 0.3556
# Epoch 69/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3067 - val_loss: 0.3642
# Epoch 70/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.3239 - val_loss: 0.3584
# Epoch 71/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.3080 - val_loss: 0.3468
# Epoch 72/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.3174 - val_loss: 0.3486
# Epoch 73/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.3030 - val_loss: 0.3371
# Epoch 74/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2919 - val_loss: 0.3352
# Epoch 75/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.2768 - val_loss: 0.3316
# Epoch 76/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.2750 - val_loss: 0.3372
# Epoch 77/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.2658 - val_loss: 0.3294
# Epoch 78/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2709 - val_loss: 0.3206
# Epoch 79/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2981 - val_loss: 0.3268
# Epoch 80/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2579 - val_loss: 0.5380
# Epoch 81/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.3441 - val_loss: 0.3318
# Epoch 82/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2871 - val_loss: 0.3556
# Epoch 83/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2884 - val_loss: 0.3121
# Epoch 84/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2852 - val_loss: 0.3312
# Epoch 85/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2515 - val_loss: 0.3015
# Epoch 86/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2561 - val_loss: 0.3018
# Epoch 87/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2713 - val_loss: 0.3627
# Epoch 88/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2592 - val_loss: 0.2921
# Epoch 89/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2398 - val_loss: 0.2938
# Epoch 90/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2611 - val_loss: 0.2894
# Epoch 91/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2399 - val_loss: 0.2884
# Epoch 92/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.2632 - val_loss: 0.2894
# Epoch 93/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.2393 - val_loss: 0.2831
# Epoch 94/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.2345 - val_loss: 0.3110
# Epoch 95/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.2541 - val_loss: 0.2829
# Epoch 96/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.2302 - val_loss: 0.2896
# Epoch 97/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2361 - val_loss: 0.2800
# Epoch 98/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.2205 - val_loss: 0.2778
# Epoch 99/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.2229 - val_loss: 0.2805
# Epoch 100/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2273 - val_loss: 0.3108
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Accuracy:  0.9598352214212152

# %% [markdown]
# #### 모델 2-2-2

# %%
clear_session()

n = x_train0.shape[1]

es = EarlyStopping(monitor = 'val_loss', min_delta = 0, patience = 3)

model4 = Sequential([Input(shape = (n, )),
                     Dense(1024, activation="relu"),
                     Dense(2048, activation="relu"),
                     Dropout(0.2),
                     Dense(512, activation="relu"),
                     Dense(256, activation="relu"),
                     Dense(64, activation="relu"),
                     Dense(16, activation="relu"),
                     Dense(3, activation = 'softmax')])


model4.compile(optimizer = Adam(learning_rate = 0.001), loss = 'sparse_categorical_crossentropy')

model4.fit(x_train0, y_train0, epochs = 50, validation_split = 0.2, callbacks = [es])

pred4 = model4.predict(x_val0)
pred4 = np.argmax(pred4, axis = 1)

print("Accuracy: ", accuracy_score(y_val0, pred4))
# Out:
# Epoch 1/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 10s 132ms/step - loss: 0.9491 - val_loss: 0.5677
# Epoch 2/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - loss: 0.4535 - val_loss: 0.3346
# Epoch 3/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step - loss: 0.2508 - val_loss: 0.2076
# Epoch 4/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 85ms/step - loss: 0.1627 - val_loss: 0.2424
# Epoch 5/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.1595 - val_loss: 0.1736
# Epoch 6/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 76ms/step - loss: 0.2469 - val_loss: 0.1580
# Epoch 7/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - loss: 0.1236 - val_loss: 0.3178
# Epoch 8/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - loss: 0.1601 - val_loss: 0.1379
# Epoch 9/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 88ms/step - loss: 0.1064 - val_loss: 0.1303
# Epoch 10/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 0.0941 - val_loss: 0.1405
# Epoch 11/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - loss: 0.1578 - val_loss: 0.1247
# Epoch 12/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 91ms/step - loss: 0.1343 - val_loss: 0.2305
# Epoch 13/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 9s 75ms/step - loss: 0.1159 - val_loss: 0.1670
# Epoch 14/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - loss: 0.1403 - val_loss: 0.1489
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# Accuracy:  0.964984552008239

# %% [markdown]
# #### 2) 단계2-2 : 동적 동작 세부 분류

# %% [markdown]
# * 세부 요구사항
#     * 동적 행동(Walking, Walking Upstairs, Walking Downstairs)인 데이터 추출
#     * Walking, Walking Upstairs, Walking Downstairs 를 분류하는 모델을 생성
#     * 몇가지 모델을 만들고 가장 성능이 좋은 모델을 선정하시오.

# %% [markdown]
# #### 모델 2-2-1

# %%
# 제일 위에 데이터 불러오고 밑에 코드들 순서대로 실행했습니다.

static_activities = ['STANDING', 'SITTING', 'LAYING']
dynamic_activities = ['WALKING', 'WALKING_UPSTAIRS', 'WALKING_DOWNSTAIRS']
data['is_dynamic'] = data['Activity'].apply(lambda x: 0 if x in static_activities else 1)
data.head()

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
data['Activity'] = encoder.fit_transform(data['Activity'])

# %%
df_1 = data.loc[data['Activity'].isin([3, 4, 5])]

# x, y 분리
target = 'Activity'
x1 = df_1.drop([target,'is_dynamic'], axis = 1)
y1 = df_1.loc[:, target] - 3

# 데이터 분할
x_train1, x_val1, y_train1, y_val1 = train_test_split(x1, y1, test_size = .3, random_state = 20)

# %%
class Modeling:
    def __init__(self, dense=[], dropout=[]):
        self.model = None
        self.dense = dense
        self.dropout = dropout

    def build_models(self, clear=True):
        if clear:
            clear_session()

        inp_layer = Input(shape=(x_train1.shape[1], )) #input도 바꿨습니다.
        out_layer = Dense(3, activation='softmax')

        model_layer = [inp_layer] # add input layer

        if len(self.dropout) != 0:
            for n, r in zip(self.dense, self.dropout): # hidden layer
                dense_ = Dense(n, activation='relu')
                dropout_ = Dropout(r)
                model_layer.append(dense_)
                model_layer.append(dropout_)
        else:
            for n in self.dense: # hidden layer
                dense_ = Dense(n, activation='relu')
                model_layer.append(dense_)

        model_layer.append(out_layer) # add output layer

        self.layers = model_layer

        model = Sequential(self.layers)
        self.model = model

    def compile_models(self, learning_rate):
        self.model.compile(
            optimizer=Adam(learning_rate),
            loss='sparse_categorical_crossentropy'
        )

    def run_models(self,
                   learning_rate=0.001, epochs=50, callbacks=[], time=1,log=True, return_preds=True):

        result = []
        f1_result = []
        history_logs = pd.DataFrame()

        for i in range(time):

            self.build_models()

            if i == 0:
                self.model.summary()

            self.compile_models(learning_rate)

            history = self.model.fit(x_train1, y_train1, # 학습값을 바꿨습니다.
                                        epochs=epochs,
                                        validation_split=0.2,
                                        verbose=0,
                                        callbacks=callbacks).history
            if log:
                history_logs[f'history_{i}'] = history

            pred = self.model.predict(x_val1) # 평가 데이터를 바꿨습니다.
            pred_label = pred.argmax(axis=1)

            result.append(accuracy_score(y_val1, pred_label))

            print(result[i])

        print("Accuracy: ", np.mean(result))

        if return_preds:
            return pred_label, result, history_logs
        else:
            return result, history_logs

# %%
LR = 0.001
EPOCHS = 50

model5 = Modeling([1024, 256, 64, 16])
y_pred, scores, history_logs = model5.run_models(LR, EPOCHS, time=1, log=True, return_preds=True)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                      │ (None, 1024)                │         575,488 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 256)                 │         262,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 64)                  │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 16)                  │           1,040 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 3)                   │              51 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 855,427 (3.26 MB)
#  Trainable params: 855,427 (3.26 MB)
#  Non-trainable params: 0 (0.00 B)
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 0.9874213836477987
# Accuracy:  0.9874213836477987

# %% [markdown]
# #### 모델 2-2-2

# %%
LR = 0.001
EPOCHS = 200

model6 = Modeling([256, 128])
y_pred, scores, history_logs = model6.run_models(LR, EPOCHS, time=1, log=True, return_preds=True)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                      │ (None, 256)                 │         143,872 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 3)                   │             387 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 177,155 (692.01 KB)
#  Trainable params: 177,155 (692.01 KB)
#  Non-trainable params: 0 (0.00 B)
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 0.9924528301886792
# Accuracy:  0.9924528301886792

# %% [markdown]
# ### (3) 분류 모델 파이프라인 구성

# %% [markdown]
# * 세부 요구사항
#     * 두 단계 모델을 통합하고, 새로운 데이터(test)에 대해서 최종 예측결과와 성능평가가 나오도록 함수로 만들기
#     * 데이터 파이프라인 구축 : test데이터가 로딩되어 전처리 과정을 거치고, 예측 및 성능 평가 수행

# %% [markdown]
# * 예시
# ![](https://github.com/DA4BAM/image/blob/main/pipeline%20function.png?raw=true)

# %% [markdown]
# #### 1) 함수 만들기

# %%
scaler_is_dynamic = MinMaxScaler()
sclaer_is_dynamic.fit_transform(x)

scaler_static = MinMaxScaler()
sclaer_static.fit_transform(x0)

scaler_dynamic = MinMaxScaler()
sclaer_dynamic.fit_transform(x1)

# %%
def get_test_performance(test_data,
                         model_is_dynamic = best_model_is_dynamic,
                         model_static = best_model_static,
                         model_dynamic = best_model_dynamic,
                         scaler_dynamic = scaler_dynamic,
                         scaler_static = scaler_static,
                         scaler_is_dynamic = scaler_is_dynamic,
                         encoder_dynamic = encoder_dynamic,
                         encoder_static = encoder_static):
  x_test, y_test = x_y_split(test_data, target="is_dynamic")
  x_test_is_dynamic = scaler_is_dynamic.transform(x_test)
  y_is_dynamic = model_is_dynamic.predict(x_test_is_dynamic)
  y_is_dynamic = y_is_dynamic.argmax(axis=1)

  test_data['is_dynamic'] = y_is_dynamic
  df_x_test = test_data.copy()
  # df_x_test = pd.DataFrame(x_test)

  # df_x_test["is_dynamic"] = y_is_dynamic

  x_static = df_x_test[df_x_test.is_dynamic == 0].drop(["Activity", "is_dynamic"], axis=1)
  y_static = df_x_test[df_x_test.is_dynamic == 0].loc[:, "Activity"]
  x_dynamic = df_x_test[df_x_test.is_dynamic == 1].drop(["Activity", "is_dynamic"], axis=1)
  y_dynamic = df_x_test[df_x_test.is_dynamic == 1].loc[:, "Activity"]

  x_static = scaler_static.transform(x_static)
  x_dynamic = scaler_dynamic.transform(x_dynamic)

  y_static_pred = model_static.predict(x_static)
  y_dynamic_pred = model_dynamic.predict(x_dynamic)

  y_static_result = y_static_pred.argmax(axis=1)
  y_dyanmic_result = y_dynamic_pred.argmax(axis=1)

  y_static_class = [encoder_static.classes_[x] for x in y_static_result]
  y_dynamic_class = [encoder_dynamic.classes_[x] for x in y_dyanmic_result]

  return accuracy_score(list(y_static) + list(y_dynamic), list(y_static_class)+list(y_dynamic_class))

# %% [markdown]
# #### 2) test 셋으로 예측하고 평가하기

# %%
acc_final = get_test_performance(test, model_is_dynamic=model4, model_dynamic=model3, model_static=model1)
acc_final
# Out:
# 0.9768864717878993
